# %%
# /// script
# requires-python = ">=3.12"
# dependencies = [
#     "aiohttp",
#     "geopy",
#     "lonboard",
# ]
# ///

# %% [markdown]
# # Geocoding with GeoPy
#
# This notebook shows how to add a geocoder drop down box to the map using the [GeoPy] library.
#
# [GeoPy]: https://geopy.readthedocs.io/en/stable/

# %% [markdown]
# ## Dependencies
#
# Install [`uv`](https://docs.astral.sh/uv) and then launch this notebook with:
#
# ```
# uvx juv run examples/geocoder-control.ipynb
# ```
#
# (The `uvx` command is included when installing `uv`).

# %% [markdown]
# ## Imports

# %%
from geopy.adapters import AioHTTPAdapter
from geopy.geocoders import Nominatim

from lonboard import Map
from lonboard.basemap import CartoStyle, MaplibreBasemap
from lonboard.controls import (
    FullscreenControl,
    GeocoderControl,
    NavigationControl,
    ScaleControl,
)

# %% [markdown]
# First, we create a new geocoder instance. GeoPy supports many different [geocoder providers]. Some may require API keys or other authentication. This is your responsibility to provide when creating the geocoder instance.
#
# [geocoder providers]: https://geopy.readthedocs.io/en/stable/#module-geopy.geocoders
#
# In our case, we'll use the [`Nominatim` class](https://geopy.readthedocs.io/en/stable/#nominatim), which is provided by <https://nominatim.org>. The Nominatim usage policy requires that you specify a custom user agent that identifies your application. In this case, we'll use the string `"lonboard-app"`.
#
# In order for the Python-browser communication to work well, it's also required that you create a geocoder in [async mode](https://geopy.readthedocs.io/en/stable/#async-mode). Here we pass in the `AioHTTPAdapter`, which ensures that geocoding requests can be done asynchronously.

# %%
geocoder = Nominatim(user_agent="lonboard-app", adapter_factory=AioHTTPAdapter)

# %% [markdown]
# Then, create a new `GeocoderControl` instance. Since we're using the GeoPy integration, we use the `from_geopy` constructor.

# %%
geocoder_control = GeocoderControl.from_geopy(geocoder)

# %% [markdown]
# Next, just include `control` in the list passed to the `controls` parameter.
#
# Note that since we're overriding the `controls` argument, if we want to restore the default controls, such as the `FullscreenControl`, `NavigationControl`, and `ScaleControl`, we'll have to add them.

# %%
controls = [geocoder_control, NavigationControl(), ScaleControl(), FullscreenControl()]
m = Map([], basemap=MaplibreBasemap(style=CartoStyle.Voyager), controls=controls)
m
# Out:
# VBox(children=(<lonboard._map.Map object at 0x109cf31a0>, VBox(children=(ErrorOutput(), ErrorOutput(), ErrorOu…
